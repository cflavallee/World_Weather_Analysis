# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + city
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description                          
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | birjand
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | vangaindrano
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | pimentel
# Processing Record 7 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 1 | hithadhoo
# Processing Record 9 of Set 1 | basco
# Processing Record 10 of Set 1 | peachtree city
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | lagoa
# Processing Record 14 of Set 1 | alyangula
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | roald
# Processing Record 18 of Set 1 | bandarbeyla
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | houma
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | ketchikan
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | manzhouli
# Processing Record 31 of Set 1 | praia da vitoria
# Processing Record 32 of Set 1 | namibe
# Processing Record 33 of Set 1 | souillac
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | kinshasa
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | omsukchan
# Processing Record 39 of Set 1 | mineiros
# Processing Record 40 of Set 1 | urumqi
# Processing Record 41 of Set 1 | goderich
# Processing Record 42 of Set 1 | scottsburgh
# City not found. Skipping...
# Processing Record 43 of Set 1 | kaitangata
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | dakar
# Processing Record 49 of Set 1 | henties bay
# Processing Record 50 of Set 1 | nileshwar
# Processing Record 1 of Set 2 | lavrentiya
# Processing Record 2 of Set 2 | hofn
# Processing Record 3 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 2 | rincon
# Processing Record 5 of Set 2 | plettenberg bay
# Processing Record 6 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 2 | ahipara
# Processing Record 8 of Set 2 | cockburn town
# Processing Record 9 of Set 2 | beysehir
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | hamilton
# Processing Record 13 of Set 2 | los llanos de aridane
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | costinesti
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | waipawa
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | mahajanga
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | dudinka
# Processing Record 23 of Set 2 | half moon bay
# Processing Record 24 of Set 2 | richmond
# Processing Record 25 of Set 2 | kirgiz-miyaki
# Processing Record 26 of Set 2 | necochea
# Processing Record 27 of Set 2 | mayo
# Processing Record 28 of Set 2 | kruisfontein
# Processing Record 29 of Set 2 | podstepki
# Processing Record 30 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 2 | road town
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | lata
# Processing Record 35 of Set 2 | labrea
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | geraldton
# Processing Record 38 of Set 2 | olafsvik
# Processing Record 39 of Set 2 | kenai
# Processing Record 40 of Set 2 | managua
# Processing Record 41 of Set 2 | severo-kurilsk
# Processing Record 42 of Set 2 | abay
# Processing Record 43 of Set 2 | codrington
# Processing Record 44 of Set 2 | provideniya
# Processing Record 45 of Set 2 | sitka
# Processing Record 46 of Set 2 | busselton
# Processing Record 47 of Set 2 | amapa
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | bonga
# Processing Record 50 of Set 2 | fare
# Processing Record 1 of Set 3 | itarema
# Processing Record 2 of Set 3 | tasiilaq
# Processing Record 3 of Set 3 | iqaluit
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | voyvozh
# Processing Record 6 of Set 3 | sabang
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | azare
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | nanortalik
# Processing Record 11 of Set 3 | poum
# Processing Record 12 of Set 3 | sao joao da barra
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | port hardy
# Processing Record 15 of Set 3 | zhireken
# Processing Record 16 of Set 3 | port hedland
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | port macquarie
# Processing Record 19 of Set 3 | rawson
# Processing Record 20 of Set 3 | itoman
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | morris
# Processing Record 23 of Set 3 | tura
# Processing Record 24 of Set 3 | iquitos
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | shetpe
# Processing Record 27 of Set 3 | potchefstroom
# Processing Record 28 of Set 3 | thompson
# Processing Record 29 of Set 3 | port alberni
# Processing Record 30 of Set 3 | fallon
# Processing Record 31 of Set 3 | pangnirtung
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | cessnock
# Processing Record 34 of Set 3 | arraial do cabo
# Processing Record 35 of Set 3 | airai
# Processing Record 36 of Set 3 | lebu
# Processing Record 37 of Set 3 | saurimo
# Processing Record 38 of Set 3 | bubaque
# Processing Record 39 of Set 3 | hasaki
# Processing Record 40 of Set 3 | quatre cocos
# Processing Record 41 of Set 3 | chegdomyn
# Processing Record 42 of Set 3 | samarai
# Processing Record 43 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 3 | jalaun
# Processing Record 45 of Set 3 | saint-philippe
# Processing Record 46 of Set 3 | kedrovyy
# Processing Record 47 of Set 3 | georgetown
# Processing Record 48 of Set 3 | novochernorechenskiy
# Processing Record 49 of Set 3 | payo
# Processing Record 50 of Set 3 | yumen
# Processing Record 1 of Set 4 | tuatapere
# Processing Record 2 of Set 4 | grindavik
# Processing Record 3 of Set 4 | nizhnyaya omka
# Processing Record 4 of Set 4 | rio gallegos
# Processing Record 5 of Set 4 | akdepe
# Processing Record 6 of Set 4 | ballina
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | coos bay
# Processing Record 9 of Set 4 | alexandria
# Processing Record 10 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 4 | bonavista
# Processing Record 12 of Set 4 | tarko-sale
# Processing Record 13 of Set 4 | alamogordo
# Processing Record 14 of Set 4 | hobart
# Processing Record 15 of Set 4 | coquimbo
# Processing Record 16 of Set 4 | kirillov
# Processing Record 17 of Set 4 | sept-iles
# Processing Record 18 of Set 4 | dingle
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 4 | mehamn
# Processing Record 21 of Set 4 | isangel
# Processing Record 22 of Set 4 | puerto narino
# Processing Record 23 of Set 4 | kismayo
# Processing Record 24 of Set 4 | bure
# Processing Record 25 of Set 4 | cam pha
# City not found. Skipping...
# Processing Record 26 of Set 4 | auki
# Processing Record 27 of Set 4 | beohari
# Processing Record 28 of Set 4 | katsuura
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | sao filipe
# Processing Record 31 of Set 4 | araouane
# Processing Record 32 of Set 4 | solnechnyy
# Processing Record 33 of Set 4 | kolimvari
# City not found. Skipping...
# Processing Record 34 of Set 4 | la macarena
# Processing Record 35 of Set 4 | port shepstone
# Processing Record 36 of Set 4 | havelock
# Processing Record 37 of Set 4 | saskylakh
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 4 | bafoulabe
# Processing Record 40 of Set 4 | villa carlos paz
# Processing Record 41 of Set 4 | saint george
# Processing Record 42 of Set 4 | sao jose da coroa grande
# Processing Record 43 of Set 4 | sitio novo do tocantins
# Processing Record 44 of Set 4 | champerico
# Processing Record 45 of Set 4 | la plata
# Processing Record 46 of Set 4 | mandalgovi
# Processing Record 47 of Set 4 | ixtapa
# Processing Record 48 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 4 | faya
# Processing Record 50 of Set 4 | sabha
# Processing Record 1 of Set 5 | salalah
# Processing Record 2 of Set 5 | vardo
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 5 | raga
# Processing Record 6 of Set 5 | leningradskiy
# Processing Record 7 of Set 5 | poco das trincheiras
# Processing Record 8 of Set 5 | porto torres
# Processing Record 9 of Set 5 | san patricio
# Processing Record 10 of Set 5 | palu
# Processing Record 11 of Set 5 | kota bahru
# Processing Record 12 of Set 5 | talnakh
# Processing Record 13 of Set 5 | vanimo
# Processing Record 14 of Set 5 | manaure
# Processing Record 15 of Set 5 | elizabethton
# Processing Record 16 of Set 5 | sabya
# Processing Record 17 of Set 5 | port elizabeth
# Processing Record 18 of Set 5 | buala
# Processing Record 19 of Set 5 | guerrero negro
# Processing Record 20 of Set 5 | ribeira grande
# Processing Record 21 of Set 5 | teguldet
# Processing Record 22 of Set 5 | clyde river
# Processing Record 23 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 5 | hay river
# Processing Record 25 of Set 5 | constitucion
# Processing Record 26 of Set 5 | caravelas
# Processing Record 27 of Set 5 | saint-augustin
# Processing Record 28 of Set 5 | vila velha
# Processing Record 29 of Set 5 | san cristobal
# Processing Record 30 of Set 5 | sanandaj
# Processing Record 31 of Set 5 | cortez
# Processing Record 32 of Set 5 | miraflores
# Processing Record 33 of Set 5 | nandura
# Processing Record 34 of Set 5 | sant feliu de guixols
# Processing Record 35 of Set 5 | paamiut
# Processing Record 36 of Set 5 | sigli
# Processing Record 37 of Set 5 | merauke
# Processing Record 38 of Set 5 | mityana
# Processing Record 39 of Set 5 | petrivka
# Processing Record 40 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | seminole
# Processing Record 44 of Set 5 | stephenville crossing
# Processing Record 45 of Set 5 | werda
# Processing Record 46 of Set 5 | port blair
# Processing Record 47 of Set 5 | bengkulu
# Processing Record 48 of Set 5 | mwinilunga
# Processing Record 49 of Set 5 | lasa
# Processing Record 50 of Set 5 | inhambane
# Processing Record 1 of Set 6 | pisco
# Processing Record 2 of Set 6 | businga
# Processing Record 3 of Set 6 | acapulco
# Processing Record 4 of Set 6 | beringovskiy
# Processing Record 5 of Set 6 | macapa
# Processing Record 6 of Set 6 | bethel
# Processing Record 7 of Set 6 | belmonte
# Processing Record 8 of Set 6 | fairbanks
# Processing Record 9 of Set 6 | broome
# Processing Record 10 of Set 6 | port lincoln
# Processing Record 11 of Set 6 | kiama
# Processing Record 12 of Set 6 | tema
# Processing Record 13 of Set 6 | benha
# City not found. Skipping...
# Processing Record 14 of Set 6 | saldanha
# Processing Record 15 of Set 6 | port-de-bouc
# Processing Record 16 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 17 of Set 6 | la asuncion
# Processing Record 18 of Set 6 | gandajika
# Processing Record 19 of Set 6 | praia
# Processing Record 20 of Set 6 | srednekolymsk
# Processing Record 21 of Set 6 | kiblawan
# Processing Record 22 of Set 6 | aitape
# Processing Record 23 of Set 6 | coihaique
# Processing Record 24 of Set 6 | cabedelo
# Processing Record 25 of Set 6 | port-gentil
# Processing Record 26 of Set 6 | east wenatchee bench
# Processing Record 27 of Set 6 | matara
# Processing Record 28 of Set 6 | fernandopolis
# Processing Record 29 of Set 6 | victoria
# Processing Record 30 of Set 6 | mende
# Processing Record 31 of Set 6 | tabou
# Processing Record 32 of Set 6 | saint-pierre
# Processing Record 33 of Set 6 | guane
# Processing Record 34 of Set 6 | hambantota
# Processing Record 35 of Set 6 | coahuayana
# Processing Record 36 of Set 6 | cap-aux-meules
# Processing Record 37 of Set 6 | lugo
# Processing Record 38 of Set 6 | antalaha
# Processing Record 39 of Set 6 | gloucester
# Processing Record 40 of Set 6 | chapais
# Processing Record 41 of Set 6 | abha
# Processing Record 42 of Set 6 | mackay
# Processing Record 43 of Set 6 | torbay
# Processing Record 44 of Set 6 | kamenka
# Processing Record 45 of Set 6 | aguada
# Processing Record 46 of Set 6 | uddevalla
# Processing Record 47 of Set 6 | te anau
# Processing Record 48 of Set 6 | chokurdakh
# Processing Record 49 of Set 6 | lorengau
# Processing Record 50 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 7 | paignton
# Processing Record 2 of Set 7 | carnarvon
# Processing Record 3 of Set 7 | pasni
# Processing Record 4 of Set 7 | gigmoto
# Processing Record 5 of Set 7 | pacifica
# Processing Record 6 of Set 7 | zhigalovo
# Processing Record 7 of Set 7 | cabo san lucas
# Processing Record 8 of Set 7 | otradnoye
# Processing Record 9 of Set 7 | kudahuvadhoo
# Processing Record 10 of Set 7 | kuytun
# Processing Record 11 of Set 7 | erzincan
# Processing Record 12 of Set 7 | baudh
# Processing Record 13 of Set 7 | husavik
# Processing Record 14 of Set 7 | tiebissou
# Processing Record 15 of Set 7 | yuanping
# Processing Record 16 of Set 7 | aden
# Processing Record 17 of Set 7 | ishigaki
# Processing Record 18 of Set 7 | ostrovnoy
# Processing Record 19 of Set 7 | lompoc
# Processing Record 20 of Set 7 | niono
# Processing Record 21 of Set 7 | dalby
# Processing Record 22 of Set 7 | northam
# Processing Record 23 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 7 | bathsheba
# Processing Record 25 of Set 7 | salinopolis
# Processing Record 26 of Set 7 | ullapool
# Processing Record 27 of Set 7 | songjianghe
# Processing Record 28 of Set 7 | marathon
# Processing Record 29 of Set 7 | lazaro cardenas
# Processing Record 30 of Set 7 | hammerfest
# Processing Record 31 of Set 7 | padang
# Processing Record 32 of Set 7 | fort nelson
# Processing Record 33 of Set 7 | tamandare
# Processing Record 34 of Set 7 | longyearbyen
# Processing Record 35 of Set 7 | cururupu
# Processing Record 36 of Set 7 | luanda
# Processing Record 37 of Set 7 | ust-ilimsk
# Processing Record 38 of Set 7 | libreville
# Processing Record 39 of Set 7 | daudnagar
# Processing Record 40 of Set 7 | arkhangelos
# City not found. Skipping...
# Processing Record 41 of Set 7 | yatou
# Processing Record 42 of Set 7 | ukiah
# Processing Record 43 of Set 7 | darhan
# Processing Record 44 of Set 7 | noshiro
# Processing Record 45 of Set 7 | deputatskiy
# Processing Record 46 of Set 7 | tateyama
# Processing Record 47 of Set 7 | billings
# Processing Record 48 of Set 7 | kununurra
# Processing Record 49 of Set 7 | soe
# Processing Record 50 of Set 7 | griffith
# Processing Record 1 of Set 8 | kalmunai
# Processing Record 2 of Set 8 | carmen
# Processing Record 3 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 8 | russell
# Processing Record 5 of Set 8 | nouadhibou
# Processing Record 6 of Set 8 | nago
# Processing Record 7 of Set 8 | ust-kuyga
# Processing Record 8 of Set 8 | yulara
# Processing Record 9 of Set 8 | fossombrone
# Processing Record 10 of Set 8 | faanui
# Processing Record 11 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 12 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 8 | haines junction
# Processing Record 14 of Set 8 | yei
# Processing Record 15 of Set 8 | kashi
# Processing Record 16 of Set 8 | milkovo
# Processing Record 17 of Set 8 | arteche
# Processing Record 18 of Set 8 | atar
# Processing Record 19 of Set 8 | karpogory
# Processing Record 20 of Set 8 | vaitape
# Processing Record 21 of Set 8 | kidal
# Processing Record 22 of Set 8 | tupik
# Processing Record 23 of Set 8 | sault sainte marie
# Processing Record 24 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 25 of Set 8 | laguna
# Processing Record 26 of Set 8 | dobrusevo
# Processing Record 27 of Set 8 | mount isa
# Processing Record 28 of Set 8 | rio verde de mato grosso
# Processing Record 29 of Set 8 | itaituba
# Processing Record 30 of Set 8 | tenenkou
# Processing Record 31 of Set 8 | iquique
# Processing Record 32 of Set 8 | hovd
# Processing Record 33 of Set 8 | tommot
# Processing Record 34 of Set 8 | evanston
# Processing Record 35 of Set 8 | zhigansk
# Processing Record 36 of Set 8 | martinho campos
# Processing Record 37 of Set 8 | marawi
# Processing Record 38 of Set 8 | tlaxco
# Processing Record 39 of Set 8 | trofors
# Processing Record 40 of Set 8 | pevek
# Processing Record 41 of Set 8 | evensk
# Processing Record 42 of Set 8 | berdigestyakh
# Processing Record 43 of Set 8 | fukue
# Processing Record 44 of Set 8 | namtsy
# Processing Record 45 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 46 of Set 8 | marzuq
# Processing Record 47 of Set 8 | ust-omchug
# Processing Record 48 of Set 8 | ara
# Processing Record 49 of Set 8 | homer
# Processing Record 50 of Set 8 | zhangye
# Processing Record 1 of Set 9 | morro bay
# Processing Record 2 of Set 9 | buraydah
# Processing Record 3 of Set 9 | wanning
# Processing Record 4 of Set 9 | tagusao
# Processing Record 5 of Set 9 | oranjemund
# Processing Record 6 of Set 9 | mirnyy
# Processing Record 7 of Set 9 | nelson bay
# Processing Record 8 of Set 9 | bratsk
# Processing Record 9 of Set 9 | burns lake
# Processing Record 10 of Set 9 | kamuli
# Processing Record 11 of Set 9 | san jeronimo
# Processing Record 12 of Set 9 | santa lucia
# Processing Record 13 of Set 9 | zaysan
# Processing Record 14 of Set 9 | slobidka
# Processing Record 15 of Set 9 | marsh harbour
# Processing Record 16 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 9 | alice springs
# Processing Record 18 of Set 9 | bantou
# Processing Record 19 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 20 of Set 9 | teeli
# Processing Record 21 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 22 of Set 9 | novobirilyussy
# Processing Record 23 of Set 9 | meulaboh
# Processing Record 24 of Set 9 | bollnas
# Processing Record 25 of Set 9 | millinocket
# Processing Record 26 of Set 9 | loreto
# Processing Record 27 of Set 9 | biak
# Processing Record 28 of Set 9 | borogontsy
# Processing Record 29 of Set 9 | kuryk
# Processing Record 30 of Set 9 | touros
# Processing Record 31 of Set 9 | eastbourne
# Processing Record 32 of Set 9 | bosaso
# Processing Record 33 of Set 9 | qui nhon
# Processing Record 34 of Set 9 | manaus
# Processing Record 35 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 9 | kulhudhuffushi
# Processing Record 37 of Set 9 | garissa
# Processing Record 38 of Set 9 | nampa
# Processing Record 39 of Set 9 | abonnema
# Processing Record 40 of Set 9 | larap
# Processing Record 41 of Set 9 | yerbogachen
# Processing Record 42 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 9 | sorong
# Processing Record 44 of Set 9 | victor harbor
# Processing Record 45 of Set 9 | ust-koksa
# Processing Record 46 of Set 9 | ina
# Processing Record 47 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 9 | puerto escondido
# Processing Record 49 of Set 9 | denpasar
# Processing Record 50 of Set 9 | foam lake
# Processing Record 1 of Set 10 | nantai
# Processing Record 2 of Set 10 | nerchinskiy zavod
# Processing Record 3 of Set 10 | viedma
# Processing Record 4 of Set 10 | opotiki
# Processing Record 5 of Set 10 | ilulissat
# Processing Record 6 of Set 10 | baykit
# Processing Record 7 of Set 10 | alofi
# Processing Record 8 of Set 10 | galle
# Processing Record 9 of Set 10 | oranjestad
# Processing Record 10 of Set 10 | hakui
# Processing Record 11 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 12 of Set 10 | dandong
# Processing Record 13 of Set 10 | megion
# Processing Record 14 of Set 10 | veraval
# Processing Record 15 of Set 10 | college
# Processing Record 16 of Set 10 | nome
# Processing Record 17 of Set 10 | grand gaube
# Processing Record 18 of Set 10 | mana
# Processing Record 19 of Set 10 | kavieng
# Processing Record 20 of Set 10 | tecolotlan
# Processing Record 21 of Set 10 | hit
# Processing Record 22 of Set 10 | lovozero
# Processing Record 23 of Set 10 | karachi
# Processing Record 24 of Set 10 | port keats
# Processing Record 25 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 10 | magan
# Processing Record 27 of Set 10 | babstovo
# Processing Record 28 of Set 10 | gizo
# Processing Record 29 of Set 10 | puerto cabezas
# Processing Record 30 of Set 10 | villa del rosario
# Processing Record 31 of Set 10 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 32 of Set 10 | nizhniy baskunchak
# Processing Record 33 of Set 10 | bowen
# Processing Record 34 of Set 10 | klyuchi
# Processing Record 35 of Set 10 | sao felix do xingu
# Processing Record 36 of Set 10 | komsomolets
# Processing Record 37 of Set 10 | miramar
# Processing Record 38 of Set 10 | seryshevo
# Processing Record 39 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 10 | santa cruz
# Processing Record 41 of Set 10 | goba
# Processing Record 42 of Set 10 | shikarpur
# Processing Record 43 of Set 10 | porto novo
# Processing Record 44 of Set 10 | conceicao da barra
# Processing Record 45 of Set 10 | le port
# Processing Record 46 of Set 10 | tautira
# Processing Record 47 of Set 10 | grande prairie
# Processing Record 48 of Set 10 | bardiyah
# Processing Record 49 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 10 | ulladulla
# Processing Record 1 of Set 11 | simao
# Processing Record 2 of Set 11 | paengaroa
# Processing Record 3 of Set 11 | katangli
# Processing Record 4 of Set 11 | ligayan
# Processing Record 5 of Set 11 | fergus falls
# Processing Record 6 of Set 11 | maceio
# Processing Record 7 of Set 11 | nizwa
# Processing Record 8 of Set 11 | conde
# Processing Record 9 of Set 11 | komsomolskiy
# Processing Record 10 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 11 | vares
# Processing Record 12 of Set 11 | korla
# Processing Record 13 of Set 11 | kahului
# Processing Record 14 of Set 11 | lahaina
# Processing Record 15 of Set 11 | esperance
# Processing Record 16 of Set 11 | hauterive
# Processing Record 17 of Set 11 | salta
# Processing Record 18 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 20 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 11 | qeshm
# Processing Record 22 of Set 11 | encantado
# Processing Record 23 of Set 11 | ciudad bolivar
# Processing Record 24 of Set 11 | boljevac
# Processing Record 25 of Set 11 | saint-joseph
# Processing Record 26 of Set 11 | polyarnyy
# Processing Record 27 of Set 11 | margate
# Processing Record 28 of Set 11 | megalopoli
# Processing Record 29 of Set 11 | monroe
# Processing Record 30 of Set 11 | hualmay
# Processing Record 31 of Set 11 | varzelandia
# Processing Record 32 of Set 11 | gubkinskiy
# Processing Record 33 of Set 11 | tunxi
# City not found. Skipping...
# Processing Record 34 of Set 11 | oussouye
# Processing Record 35 of Set 11 | domodossola
# Processing Record 36 of Set 11 | kawalu
# Processing Record 37 of Set 11 | kavaratti
# Processing Record 38 of Set 11 | aksu
# Processing Record 39 of Set 11 | the valley
# Processing Record 40 of Set 11 | aswan
# Processing Record 41 of Set 11 | qom
# Processing Record 42 of Set 11 | antanifotsy
# Processing Record 43 of Set 11 | gbadolite
# Processing Record 44 of Set 11 | mezen
# Processing Record 45 of Set 11 | caucaia
# Processing Record 46 of Set 11 | mouzakion
# City not found. Skipping...
# Processing Record 47 of Set 11 | muskegon
# Processing Record 48 of Set 11 | kopanskaya
# Processing Record 49 of Set 11 | sakakah
# Processing Record 50 of Set 11 | erzin
# Processing Record 1 of Set 12 | wote
# Processing Record 2 of Set 12 | moron
# Processing Record 3 of Set 12 | peniche
# Processing Record 4 of Set 12 | rocha
# Processing Record 5 of Set 12 | rio grande
# Processing Record 6 of Set 12 | saint-francois
# Processing Record 7 of Set 12 | alta floresta
# Processing Record 8 of Set 12 | kousseri
# Processing Record 9 of Set 12 | orbetello
# Processing Record 10 of Set 12 | nicolas bravo
# Processing Record 11 of Set 12 | usinsk
# Processing Record 12 of Set 12 | pemangkat
# Processing Record 13 of Set 12 | richards bay
# Processing Record 14 of Set 12 | riverton
# Processing Record 15 of Set 12 | sao sebastiao
# Processing Record 16 of Set 12 | maniitsoq
# Processing Record 17 of Set 12 | aakirkeby
# City not found. Skipping...
# Processing Record 18 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 12 | cao bang
# Processing Record 20 of Set 12 | asau
# Processing Record 21 of Set 12 | cicero dantas
# Processing Record 22 of Set 12 | vestmannaeyjar
# Processing Record 23 of Set 12 | zhezkazgan
# Processing Record 24 of Set 12 | mangile
# City not found. Skipping...
# Processing Record 25 of Set 12 | gawler
# Processing Record 26 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 12 | esik
# Processing Record 28 of Set 12 | maldonado
# Processing Record 29 of Set 12 | ahuimanu
# Processing Record 30 of Set 12 | hohhot
# Processing Record 31 of Set 12 | natal
# Processing Record 32 of Set 12 | pucara
# Processing Record 33 of Set 12 | kondinskoye
# Processing Record 34 of Set 12 | katha
# City not found. Skipping...
# Processing Record 35 of Set 12 | naze
# Processing Record 36 of Set 12 | mpulungu
# Processing Record 37 of Set 12 | talca
# Processing Record 38 of Set 12 | senanga
# Processing Record 39 of Set 12 | kameshkovo
# Processing Record 40 of Set 12 | bintulu
# Processing Record 41 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 12 | ferme-neuve
# Processing Record 43 of Set 12 | sao miguel do araguaia
# Processing Record 44 of Set 12 | san rafael
# Processing Record 45 of Set 12 | high rock
# Processing Record 46 of Set 12 | khartoum
# Processing Record 47 of Set 12 | stabat
# Processing Record 48 of Set 12 | axim
# Processing Record 49 of Set 12 | talpa
# Processing Record 50 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 13 | akranes
# Processing Record 2 of Set 13 | gamba
# Processing Record 3 of Set 13 | riyadh
# Processing Record 4 of Set 13 | kieta
# Processing Record 5 of Set 13 | bereda
# Processing Record 6 of Set 13 | yalova
# Processing Record 7 of Set 13 | la ronge
# Processing Record 8 of Set 13 | sambava
# Processing Record 9 of Set 13 | kamina
# Processing Record 10 of Set 13 | brigantine
# Processing Record 11 of Set 13 | mexico
# Processing Record 12 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 13 | hami
# Processing Record 14 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 13 | batagay-alyta
# Processing Record 16 of Set 13 | kudchi
# City not found. Skipping...
# Processing Record 17 of Set 13 | yangshe
# Processing Record 18 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 19 of Set 13 | bambanglipuro
# Processing Record 20 of Set 13 | pittsburg
# Processing Record 21 of Set 13 | fuerte olimpo
# Processing Record 22 of Set 13 | siva
# Processing Record 23 of Set 13 | san fernando
# Processing Record 24 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 25 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 13 | le passage
# Processing Record 27 of Set 13 | filimonovo
# Processing Record 28 of Set 13 | ergani
# Processing Record 29 of Set 13 | gazli
# Processing Record 30 of Set 13 | yar-sale
# Processing Record 31 of Set 13 | gat
# Processing Record 32 of Set 13 | abashiri
# Processing Record 33 of Set 13 | kuandian
# Processing Record 34 of Set 13 | sungaipenuh
# Processing Record 35 of Set 13 | sampit
# Processing Record 36 of Set 13 | xinye
# Processing Record 37 of Set 13 | damietta
# Processing Record 38 of Set 13 | florence
# Processing Record 39 of Set 13 | ban phai
# Processing Record 40 of Set 13 | romanovo
# Processing Record 41 of Set 13 | iskateley
# Processing Record 42 of Set 13 | ebano
# City not found. Skipping...
# Processing Record 43 of Set 13 | westport
# Processing Record 44 of Set 13 | mecca
# Processing Record 45 of Set 13 | middelburg
# Processing Record 46 of Set 13 | karasburg
# Processing Record 47 of Set 13 | canto do buriti
# Processing Record 48 of Set 13 | maraa
# Processing Record 49 of Set 13 | makokou
# Processing Record 50 of Set 13 | zhaoyuan
# Processing Record 1 of Set 14 | odessa
# Processing Record 2 of Set 14 | lubao
# Processing Record 3 of Set 14 | bilma
# Processing Record 4 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 14 | kelvington
# Processing Record 6 of Set 14 | aklavik
# Processing Record 7 of Set 14 | shaunavon
# Processing Record 8 of Set 14 | treinta y tres
# Processing Record 9 of Set 14 | qaqortoq
# Processing Record 10 of Set 14 | inyonga
# Processing Record 11 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 14 | kumi
# Processing Record 13 of Set 14 | devils lake
# Processing Record 14 of Set 14 | carver
# Processing Record 15 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 14 | bilibino
# Processing Record 17 of Set 14 | roma
# Processing Record 18 of Set 14 | cooma
# Processing Record 19 of Set 14 | muros
# Processing Record 20 of Set 14 | la paz
# Processing Record 21 of Set 14 | suzu
# City not found. Skipping...
# Processing Record 22 of Set 14 | jalu
# Processing Record 23 of Set 14 | belgrade
# Processing Record 24 of Set 14 | walvis bay
# Processing Record 25 of Set 14 | catamarca
# Processing Record 26 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 27 of Set 14 | jacareacanga
# Processing Record 28 of Set 14 | baker city
# Processing Record 29 of Set 14 | alappuzha
# Processing Record 30 of Set 14 | vostok
# Processing Record 31 of Set 14 | kloulklubed
# Processing Record 32 of Set 14 | raudeberg
# Processing Record 33 of Set 14 | nyurba
# Processing Record 34 of Set 14 | nianzishan
# Processing Record 35 of Set 14 | lima
# Processing Record 36 of Set 14 | dunedin
# Processing Record 37 of Set 14 | wampusirpi
# City not found. Skipping...
# Processing Record 38 of Set 14 | beisfjord
# Processing Record 39 of Set 14 | nalut
# Processing Record 40 of Set 14 | verkhovazhye
# Processing Record 41 of Set 14 | tual
# Processing Record 42 of Set 14 | xichang
# Processing Record 43 of Set 14 | dunmore east
# Processing Record 44 of Set 14 | mayumba
# Processing Record 45 of Set 14 | brae
# Processing Record 46 of Set 14 | petauke
# Processing Record 47 of Set 14 | rorvik
# Processing Record 48 of Set 14 | tamiahua
# Processing Record 49 of Set 14 | arcachon
# Processing Record 50 of Set 14 | vuktyl
# Processing Record 1 of Set 15 | shar
# Processing Record 2 of Set 15 | umea
# Processing Record 3 of Set 15 | arlit
# Processing Record 4 of Set 15 | bang saphan
# Processing Record 5 of Set 15 | kyzyl-suu
# Processing Record 6 of Set 15 | camopi
# Processing Record 7 of Set 15 | pokanayevka
# City not found. Skipping...
# Processing Record 8 of Set 15 | gimli
# Processing Record 9 of Set 15 | mahonda
# Processing Record 10 of Set 15 | quthing
# Processing Record 11 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 15 | morant bay
# Processing Record 13 of Set 15 | tuy hoa
# Processing Record 14 of Set 15 | kabinda
# Processing Record 15 of Set 15 | fez
# Processing Record 16 of Set 15 | sokur
# Processing Record 17 of Set 15 | orlik
# Processing Record 18 of Set 15 | ekibastuz
# Processing Record 19 of Set 15 | stromness
# Processing Record 20 of Set 15 | vao
# Processing Record 21 of Set 15 | dobrun
# Processing Record 22 of Set 15 | kirakira
# Processing Record 23 of Set 15 | szigetszentmiklos
# Processing Record 24 of Set 15 | luwingu
# Processing Record 25 of Set 15 | sola
# Processing Record 26 of Set 15 | altus
# Processing Record 27 of Set 15 | benalla
# Processing Record 28 of Set 15 | linxia
# Processing Record 29 of Set 15 | qasigiannguit
# Processing Record 30 of Set 15 | ivnya
# Processing Record 31 of Set 15 | imeni babushkina
# Processing Record 32 of Set 15 | wanaka
# Processing Record 33 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 15 | berlevag
# Processing Record 35 of Set 15 | ornskoldsvik
# Processing Record 36 of Set 15 | groton
# Processing Record 37 of Set 15 | flinders
# Processing Record 38 of Set 15 | loandjili
# Processing Record 39 of Set 15 | puerto quijarro
# Processing Record 40 of Set 15 | xam nua
# Processing Record 41 of Set 15 | kapustin yar
# Processing Record 42 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 43 of Set 15 | zhuanghe
# Processing Record 44 of Set 15 | novovarshavka
# Processing Record 45 of Set 15 | along
# Processing Record 46 of Set 15 | makakilo city
# Processing Record 47 of Set 15 | atasu
# Processing Record 48 of Set 15 | oktyabrskiy
# Processing Record 49 of Set 15 | astara
# Processing Record 50 of Set 15 | ondjiva
# Processing Record 1 of Set 16 | dawlatabad
# Processing Record 2 of Set 16 | vadso
# Processing Record 3 of Set 16 | havoysund
# Processing Record 4 of Set 16 | ancud
# Processing Record 5 of Set 16 | namatanai
# Processing Record 6 of Set 16 | general pico
# Processing Record 7 of Set 16 | eureka
# Processing Record 8 of Set 16 | puerto penasco
# Processing Record 9 of Set 16 | kutum
# Processing Record 10 of Set 16 | alekseyevka
# Processing Record 11 of Set 16 | narasannapeta
# Processing Record 12 of Set 16 | tilichiki
# Processing Record 13 of Set 16 | prince rupert
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

city_data_df.to_csv("WeatherPy_Database.csv")

# %%
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Birjand      IR  32.8663   59.2211     49.93        40           0
# 1     Port Alfred      ZA -33.5906   26.8910     66.94        96         100
# 2    Vangaindrano      MG -23.3500   47.6000     63.30        71          17
# 3            Hilo      US  19.7297 -155.0900     82.13        71           1
# 4        Pimentel      PE  -6.8367  -79.9342     66.49        72           0
# 5       Hithadhoo      MV  -0.6000   73.0833     82.89        75         100
# 6           Basco      PH  20.4487  121.9702     79.09        70         100
# 7  Peachtree City      US  33.3968  -84.5958     67.44        83           1
# 8      Nikolskoye      RU  59.7035   30.7861     46.87        93         100
# 9         Mataura      NZ -46.1927  168.8643     64.22        61          24
#
#    Wind Speed Current Description
# 0        2.64           clear sky
# 1        6.22          light rain
# 2       11.01          few clouds
# 3       11.50           clear sky
# 4       20.71           clear sky
# 5       12.95     overcast clouds
# 6       20.13     overcast clouds
# 7        3.00           clear sky
# 8       10.83       moderate rain
# 9        1.50          few clouds
