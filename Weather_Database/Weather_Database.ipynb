# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + city
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tahta
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | yantongshan
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 1 | menongue
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | isangel
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | karasuk
# Processing Record 12 of Set 1 | tecoanapa
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | batagay
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | capaci
# Processing Record 22 of Set 1 | xinmin
# Processing Record 23 of Set 1 | wanning
# Processing Record 24 of Set 1 | broken hill
# Processing Record 25 of Set 1 | bilma
# Processing Record 26 of Set 1 | asfi
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | cayenne
# Processing Record 29 of Set 1 | provideniya
# Processing Record 30 of Set 1 | olafsvik
# Processing Record 31 of Set 1 | port hardy
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | kaka
# Processing Record 34 of Set 1 | teknaf
# Processing Record 35 of Set 1 | mtwara
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | codrington
# Processing Record 38 of Set 1 | leningradskiy
# Processing Record 39 of Set 1 | guanambi
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | nioro
# Processing Record 42 of Set 1 | zyryanka
# Processing Record 43 of Set 1 | hastings
# Processing Record 44 of Set 1 | mount isa
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | corner brook
# Processing Record 50 of Set 1 | vitimskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | vaitape
# Processing Record 2 of Set 2 | lavrentiya
# Processing Record 3 of Set 2 | belaya gora
# Processing Record 4 of Set 2 | norman wells
# Processing Record 5 of Set 2 | maiduguri
# Processing Record 6 of Set 2 | iquique
# Processing Record 7 of Set 2 | geraldton
# Processing Record 8 of Set 2 | gangotri
# City not found. Skipping...
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | ponta delgada
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | barreirinhas
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | muros
# Processing Record 17 of Set 2 | darnah
# Processing Record 18 of Set 2 | saint-georges
# Processing Record 19 of Set 2 | kodinsk
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | cheyenne
# Processing Record 23 of Set 2 | singaparna
# Processing Record 24 of Set 2 | coahuayana
# Processing Record 25 of Set 2 | vaini
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | takab
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | uncia
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | lakatoro
# Processing Record 32 of Set 2 | yongan
# Processing Record 33 of Set 2 | arlit
# Processing Record 34 of Set 2 | megion
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | mangaratiba
# Processing Record 37 of Set 2 | carnarvon
# Processing Record 38 of Set 2 | mosquera
# Processing Record 39 of Set 2 | springdale
# Processing Record 40 of Set 2 | fairbanks
# Processing Record 41 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 2 | half moon bay
# Processing Record 43 of Set 2 | ereymentau
# Processing Record 44 of Set 2 | gillette
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | iwanai
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | moundou
# Processing Record 49 of Set 2 | bethel
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | taldan
# Processing Record 2 of Set 3 | tucupita
# Processing Record 3 of Set 3 | biguacu
# Processing Record 4 of Set 3 | alimanguan
# City not found. Skipping...
# Processing Record 5 of Set 3 | guayabal de siquima
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 3 | takestan
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | bengkulu
# Processing Record 11 of Set 3 | inirida
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | manicore
# Processing Record 14 of Set 3 | kihei
# Processing Record 15 of Set 3 | san juan
# Processing Record 16 of Set 3 | maldonado
# Processing Record 17 of Set 3 | iqaluit
# Processing Record 18 of Set 3 | livingston
# Processing Record 19 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 20 of Set 3 | preobrazheniye
# Processing Record 21 of Set 3 | dingle
# Processing Record 22 of Set 3 | chokurdakh
# Processing Record 23 of Set 3 | paamiut
# Processing Record 24 of Set 3 | inuvik
# Processing Record 25 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 3 | atuona
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | clyde river
# Processing Record 29 of Set 3 | sao raimundo nonato
# Processing Record 30 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 3 | saskylakh
# Processing Record 32 of Set 3 | peterhead
# Processing Record 33 of Set 3 | tasiilaq
# Processing Record 34 of Set 3 | ponta do sol
# Processing Record 35 of Set 3 | shingu
# Processing Record 36 of Set 3 | coquimbo
# Processing Record 37 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 3 | erice
# Processing Record 39 of Set 3 | huangchuan
# Processing Record 40 of Set 3 | hualmay
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | hofn
# Processing Record 43 of Set 3 | aiken
# Processing Record 44 of Set 3 | dayong
# Processing Record 45 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 3 | kaitangata
# Processing Record 47 of Set 3 | ninotsminda
# Processing Record 48 of Set 3 | berezovyy
# Processing Record 49 of Set 3 | rotselaar
# Processing Record 50 of Set 3 | elliot
# Processing Record 1 of Set 4 | bang saphan
# Processing Record 2 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 4 | souillac
# Processing Record 4 of Set 4 | labuhan
# Processing Record 5 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 4 | qaanaaq
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | road town
# Processing Record 10 of Set 4 | fethiye
# Processing Record 11 of Set 4 | gumdag
# Processing Record 12 of Set 4 | pamanukan
# Processing Record 13 of Set 4 | lubuagan
# Processing Record 14 of Set 4 | aksu
# Processing Record 15 of Set 4 | victoria point
# Processing Record 16 of Set 4 | acapulco
# Processing Record 17 of Set 4 | college
# Processing Record 18 of Set 4 | ugoofaaru
# Processing Record 19 of Set 4 | san jose
# Processing Record 20 of Set 4 | lompoc
# Processing Record 21 of Set 4 | mahebourg
# Processing Record 22 of Set 4 | alice springs
# Processing Record 23 of Set 4 | butaritari
# Processing Record 24 of Set 4 | mehamn
# Processing Record 25 of Set 4 | noumea
# Processing Record 26 of Set 4 | iznik
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | okha
# Processing Record 29 of Set 4 | broome
# Processing Record 30 of Set 4 | asau
# Processing Record 31 of Set 4 | liusha
# Processing Record 32 of Set 4 | hovd
# Processing Record 33 of Set 4 | lata
# Processing Record 34 of Set 4 | la ronge
# Processing Record 35 of Set 4 | homer
# Processing Record 36 of Set 4 | sao jose da coroa grande
# Processing Record 37 of Set 4 | azul
# Processing Record 38 of Set 4 | chicama
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | haines junction
# Processing Record 42 of Set 4 | ibotirama
# Processing Record 43 of Set 4 | kindu
# Processing Record 44 of Set 4 | katsuura
# Processing Record 45 of Set 4 | basyanovskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | kahului
# Processing Record 47 of Set 4 | guerrero negro
# Processing Record 48 of Set 4 | bathsheba
# Processing Record 49 of Set 4 | hamilton
# Processing Record 50 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 5 | gondanglegi
# Processing Record 2 of Set 5 | vila franca do campo
# Processing Record 3 of Set 5 | santa isabel do rio negro
# Processing Record 4 of Set 5 | macapa
# Processing Record 5 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 5 | faanui
# Processing Record 7 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 5 | horadiz
# Processing Record 9 of Set 5 | hanyang
# Processing Record 10 of Set 5 | hasaki
# Processing Record 11 of Set 5 | kavaratti
# Processing Record 12 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 5 | komsomolskiy
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | dori
# Processing Record 16 of Set 5 | klaksvik
# Processing Record 17 of Set 5 | ketchikan
# Processing Record 18 of Set 5 | calvinia
# Processing Record 19 of Set 5 | barstow
# Processing Record 20 of Set 5 | yeniseysk
# Processing Record 21 of Set 5 | hithadhoo
# Processing Record 22 of Set 5 | lososina
# Processing Record 23 of Set 5 | rudbar
# Processing Record 24 of Set 5 | wentzville
# Processing Record 25 of Set 5 | rocha
# Processing Record 26 of Set 5 | crib point
# Processing Record 27 of Set 5 | port macquarie
# Processing Record 28 of Set 5 | linguere
# Processing Record 29 of Set 5 | harper
# Processing Record 30 of Set 5 | burica
# City not found. Skipping...
# Processing Record 31 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 5 | wenatchee
# Processing Record 33 of Set 5 | lar
# Processing Record 34 of Set 5 | simao
# Processing Record 35 of Set 5 | los llanos de aridane
# Processing Record 36 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 5 | kaeo
# Processing Record 38 of Set 5 | yate
# Processing Record 39 of Set 5 | touros
# Processing Record 40 of Set 5 | hun
# Processing Record 41 of Set 5 | port elizabeth
# Processing Record 42 of Set 5 | chateaubelair
# Processing Record 43 of Set 5 | sidney
# Processing Record 44 of Set 5 | saint-augustin
# Processing Record 45 of Set 5 | port lincoln
# Processing Record 46 of Set 5 | nouadhibou
# Processing Record 47 of Set 5 | yumen
# Processing Record 48 of Set 5 | bandarbeyla
# Processing Record 49 of Set 5 | sao filipe
# Processing Record 50 of Set 5 | salalah
# Processing Record 1 of Set 6 | gat
# Processing Record 2 of Set 6 | murray bridge
# Processing Record 3 of Set 6 | paraopeba
# Processing Record 4 of Set 6 | altay
# Processing Record 5 of Set 6 | koszalin
# Processing Record 6 of Set 6 | yerbogachen
# Processing Record 7 of Set 6 | kibala
# Processing Record 8 of Set 6 | aklavik
# Processing Record 9 of Set 6 | umm kaddadah
# Processing Record 10 of Set 6 | necochea
# Processing Record 11 of Set 6 | caravelas
# Processing Record 12 of Set 6 | vila
# Processing Record 13 of Set 6 | ahar
# Processing Record 14 of Set 6 | talnakh
# Processing Record 15 of Set 6 | makinsk
# Processing Record 16 of Set 6 | marquette
# Processing Record 17 of Set 6 | omsukchan
# Processing Record 18 of Set 6 | pangnirtung
# Processing Record 19 of Set 6 | laramie
# Processing Record 20 of Set 6 | srednekolymsk
# Processing Record 21 of Set 6 | san andres
# Processing Record 22 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 6 | alenquer
# Processing Record 24 of Set 6 | vao
# Processing Record 25 of Set 6 | takaka
# Processing Record 26 of Set 6 | sarakhs
# Processing Record 27 of Set 6 | north las vegas
# Processing Record 28 of Set 6 | anchorage
# Processing Record 29 of Set 6 | christchurch
# Processing Record 30 of Set 6 | luderitz
# Processing Record 31 of Set 6 | soe
# Processing Record 32 of Set 6 | miri
# Processing Record 33 of Set 6 | odweyne
# Processing Record 34 of Set 6 | howard springs
# Processing Record 35 of Set 6 | rexburg
# Processing Record 36 of Set 6 | kodinar
# Processing Record 37 of Set 6 | aransas pass
# Processing Record 38 of Set 6 | moyale
# Processing Record 39 of Set 6 | yakeshi
# Processing Record 40 of Set 6 | beyneu
# Processing Record 41 of Set 6 | grenville
# Processing Record 42 of Set 6 | newport
# Processing Record 43 of Set 6 | melfi
# Processing Record 44 of Set 6 | waddan
# Processing Record 45 of Set 6 | leh
# Processing Record 46 of Set 6 | sur
# Processing Record 47 of Set 6 | nsanje
# Processing Record 48 of Set 6 | maniitsoq
# Processing Record 49 of Set 6 | puerto el triunfo
# Processing Record 50 of Set 6 | miles city
# Processing Record 1 of Set 7 | erenhot
# Processing Record 2 of Set 7 | axim
# Processing Record 3 of Set 7 | ixtapa
# Processing Record 4 of Set 7 | laguna
# Processing Record 5 of Set 7 | big rapids
# Processing Record 6 of Set 7 | kaseda
# Processing Record 7 of Set 7 | burnie
# Processing Record 8 of Set 7 | hangal
# Processing Record 9 of Set 7 | cochrane
# Processing Record 10 of Set 7 | ahipara
# Processing Record 11 of Set 7 | sept-iles
# Processing Record 12 of Set 7 | praia da vitoria
# Processing Record 13 of Set 7 | port blair
# Processing Record 14 of Set 7 | benalla
# Processing Record 15 of Set 7 | mitu
# Processing Record 16 of Set 7 | tuatapere
# Processing Record 17 of Set 7 | yulara
# Processing Record 18 of Set 7 | beringovskiy
# Processing Record 19 of Set 7 | torbay
# Processing Record 20 of Set 7 | meulaboh
# Processing Record 21 of Set 7 | barahan
# Processing Record 22 of Set 7 | daokou
# Processing Record 23 of Set 7 | kuytun
# Processing Record 24 of Set 7 | naze
# Processing Record 25 of Set 7 | maragogi
# Processing Record 26 of Set 7 | tual
# Processing Record 27 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 7 | santa maria
# Processing Record 29 of Set 7 | stromness
# Processing Record 30 of Set 7 | antalaha
# Processing Record 31 of Set 7 | asilah
# Processing Record 32 of Set 7 | saint-pierre
# Processing Record 33 of Set 7 | puerto quijarro
# Processing Record 34 of Set 7 | springbok
# Processing Record 35 of Set 7 | ronneby
# Processing Record 36 of Set 7 | paso de los toros
# Processing Record 37 of Set 7 | evensk
# Processing Record 38 of Set 7 | campos belos
# Processing Record 39 of Set 7 | lodwar
# Processing Record 40 of Set 7 | chincha alta
# Processing Record 41 of Set 7 | tabou
# Processing Record 42 of Set 7 | sao joao da barra
# Processing Record 43 of Set 7 | penzance
# Processing Record 44 of Set 7 | puerto ayacucho
# Processing Record 45 of Set 7 | khelyulya
# Processing Record 46 of Set 7 | takoradi
# Processing Record 47 of Set 7 | piacabucu
# Processing Record 48 of Set 7 | scarborough
# Processing Record 49 of Set 7 | lorengau
# Processing Record 50 of Set 7 | novorudnyy
# Processing Record 1 of Set 8 | yerofey pavlovich
# Processing Record 2 of Set 8 | mirnyy
# Processing Record 3 of Set 8 | itarema
# Processing Record 4 of Set 8 | kisarawe
# Processing Record 5 of Set 8 | tiksi
# Processing Record 6 of Set 8 | dalbandin
# Processing Record 7 of Set 8 | morehead
# Processing Record 8 of Set 8 | airai
# Processing Record 9 of Set 8 | tommot
# Processing Record 10 of Set 8 | kiama
# Processing Record 11 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 12 of Set 8 | vostok
# Processing Record 13 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 8 | surt
# Processing Record 15 of Set 8 | alofi
# Processing Record 16 of Set 8 | ust-ishim
# Processing Record 17 of Set 8 | northam
# Processing Record 18 of Set 8 | aberystwyth
# Processing Record 19 of Set 8 | acarau
# Processing Record 20 of Set 8 | fresno
# Processing Record 21 of Set 8 | anadyr
# Processing Record 22 of Set 8 | nuevo progreso
# Processing Record 23 of Set 8 | asbe teferi
# Processing Record 24 of Set 8 | russell
# Processing Record 25 of Set 8 | cap malheureux
# Processing Record 26 of Set 8 | manzil jamil
# City not found. Skipping...
# Processing Record 27 of Set 8 | esperance
# Processing Record 28 of Set 8 | novikovo
# Processing Record 29 of Set 8 | san anselmo
# Processing Record 30 of Set 8 | chapais
# Processing Record 31 of Set 8 | terrace
# Processing Record 32 of Set 8 | pokhara
# Processing Record 33 of Set 8 | sinazongwe
# Processing Record 34 of Set 8 | aginskoye
# Processing Record 35 of Set 8 | chuy
# Processing Record 36 of Set 8 | grand gaube
# Processing Record 37 of Set 8 | hede
# Processing Record 38 of Set 8 | ahuimanu
# Processing Record 39 of Set 8 | mezen
# Processing Record 40 of Set 8 | mercedes
# Processing Record 41 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 8 | rundu
# Processing Record 43 of Set 8 | dedovichi
# Processing Record 44 of Set 8 | meadow lake
# Processing Record 45 of Set 8 | maceio
# Processing Record 46 of Set 8 | ayan
# Processing Record 47 of Set 8 | isla mujeres
# Processing Record 48 of Set 8 | longyearbyen
# Processing Record 49 of Set 8 | amuntai
# Processing Record 50 of Set 8 | flinders
# Processing Record 1 of Set 9 | gallipoli
# Processing Record 2 of Set 9 | shitanjing
# Processing Record 3 of Set 9 | behshahr
# Processing Record 4 of Set 9 | narsaq
# Processing Record 5 of Set 9 | dandong
# Processing Record 6 of Set 9 | fomboni
# Processing Record 7 of Set 9 | tucuman
# Processing Record 8 of Set 9 | grand island
# Processing Record 9 of Set 9 | luganville
# Processing Record 10 of Set 9 | kriel
# Processing Record 11 of Set 9 | atar
# Processing Record 12 of Set 9 | harlingen
# Processing Record 13 of Set 9 | vytegra
# Processing Record 14 of Set 9 | maarianhamina
# Processing Record 15 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 9 | saldanha
# Processing Record 17 of Set 9 | shimoda
# Processing Record 18 of Set 9 | saint-paul
# Processing Record 19 of Set 9 | montoro
# Processing Record 20 of Set 9 | cheremnoye
# Processing Record 21 of Set 9 | nome
# Processing Record 22 of Set 9 | santa cruz
# Processing Record 23 of Set 9 | buala
# Processing Record 24 of Set 9 | raudeberg
# Processing Record 25 of Set 9 | vardo
# Processing Record 26 of Set 9 | antofagasta
# Processing Record 27 of Set 9 | bilibino
# Processing Record 28 of Set 9 | zonguldak
# Processing Record 29 of Set 9 | macroom
# Processing Record 30 of Set 9 | nantucket
# Processing Record 31 of Set 9 | champerico
# Processing Record 32 of Set 9 | qaqortoq
# Processing Record 33 of Set 9 | inongo
# Processing Record 34 of Set 9 | valdivia
# Processing Record 35 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 9 | kondinskoye
# Processing Record 37 of Set 9 | fredericton
# Processing Record 38 of Set 9 | erzin
# Processing Record 39 of Set 9 | mackenzie
# Processing Record 40 of Set 9 | comodoro rivadavia
# Processing Record 41 of Set 9 | hagere selam
# Processing Record 42 of Set 9 | darhan
# Processing Record 43 of Set 9 | emba
# Processing Record 44 of Set 9 | nanortalik
# Processing Record 45 of Set 9 | kosh-agach
# Processing Record 46 of Set 9 | ofaqim
# Processing Record 47 of Set 9 | obihiro
# Processing Record 48 of Set 9 | progreso
# Processing Record 49 of Set 9 | saint anthony
# Processing Record 50 of Set 9 | fallon
# Processing Record 1 of Set 10 | milingimbi
# City not found. Skipping...
# Processing Record 2 of Set 10 | turochak
# Processing Record 3 of Set 10 | lyuban
# Processing Record 4 of Set 10 | saint-ambroise
# Processing Record 5 of Set 10 | ginir
# Processing Record 6 of Set 10 | ola
# Processing Record 7 of Set 10 | teguise
# Processing Record 8 of Set 10 | adrar
# Processing Record 9 of Set 10 | sioux lookout
# Processing Record 10 of Set 10 | port-gentil
# Processing Record 11 of Set 10 | sola
# Processing Record 12 of Set 10 | pringsewu
# Processing Record 13 of Set 10 | otane
# Processing Record 14 of Set 10 | athabasca
# Processing Record 15 of Set 10 | rio branco
# Processing Record 16 of Set 10 | alta floresta
# Processing Record 17 of Set 10 | saravan
# Processing Record 18 of Set 10 | santa isabel
# Processing Record 19 of Set 10 | brae
# Processing Record 20 of Set 10 | sinnamary
# Processing Record 21 of Set 10 | partenit
# Processing Record 22 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 10 | honningsvag
# Processing Record 24 of Set 10 | sitka
# Processing Record 25 of Set 10 | san quintin
# Processing Record 26 of Set 10 | thinadhoo
# Processing Record 27 of Set 10 | japura
# Processing Record 28 of Set 10 | hare bay
# Processing Record 29 of Set 10 | kalmunai
# Processing Record 30 of Set 10 | vestmannaeyjar
# Processing Record 31 of Set 10 | uk
# City not found. Skipping...
# Processing Record 32 of Set 10 | putla
# City not found. Skipping...
# Processing Record 33 of Set 10 | pauini
# Processing Record 34 of Set 10 | esmeralda
# Processing Record 35 of Set 10 | gayeri
# Processing Record 36 of Set 10 | metkovic
# Processing Record 37 of Set 10 | cairns
# Processing Record 38 of Set 10 | san ramon de la nueva oran
# Processing Record 39 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 10 | eresos
# Processing Record 41 of Set 10 | trairi
# Processing Record 42 of Set 10 | kuito
# Processing Record 43 of Set 10 | pierre
# Processing Record 44 of Set 10 | rorvik
# Processing Record 45 of Set 10 | tiarei
# Processing Record 46 of Set 10 | college station
# Processing Record 47 of Set 10 | macau
# Processing Record 48 of Set 10 | porto walter
# Processing Record 49 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 50 of Set 10 | gaurela
# Processing Record 1 of Set 11 | aripuana
# Processing Record 2 of Set 11 | pitimbu
# Processing Record 3 of Set 11 | grindavik
# Processing Record 4 of Set 11 | ucluelet
# Processing Record 5 of Set 11 | mikhaylovskoye
# Processing Record 6 of Set 11 | hilton head island
# Processing Record 7 of Set 11 | pisco
# Processing Record 8 of Set 11 | havre-saint-pierre
# Processing Record 9 of Set 11 | dillon
# Processing Record 10 of Set 11 | awjilah
# Processing Record 11 of Set 11 | ust-omchug
# Processing Record 12 of Set 11 | kusti
# Processing Record 13 of Set 11 | dunedin
# Processing Record 14 of Set 11 | baracoa
# Processing Record 15 of Set 11 | mecca
# Processing Record 16 of Set 11 | gloversville
# Processing Record 17 of Set 11 | motygino
# Processing Record 18 of Set 11 | port hedland
# Processing Record 19 of Set 11 | naryan-mar
# Processing Record 20 of Set 11 | bam
# Processing Record 21 of Set 11 | samarai
# Processing Record 22 of Set 11 | bondo
# Processing Record 23 of Set 11 | nautla
# Processing Record 24 of Set 11 | egvekinot
# Processing Record 25 of Set 11 | karratha
# Processing Record 26 of Set 11 | severo-kurilsk
# Processing Record 27 of Set 11 | portobelo
# Processing Record 28 of Set 11 | umm lajj
# Processing Record 29 of Set 11 | mattru
# Processing Record 30 of Set 11 | la rioja
# Processing Record 31 of Set 11 | presidencia roque saenz pena
# Processing Record 32 of Set 11 | state college
# Processing Record 33 of Set 11 | muli
# Processing Record 34 of Set 11 | tilichiki
# Processing Record 35 of Set 11 | namatanai
# Processing Record 36 of Set 11 | san carlos de bariloche
# Processing Record 37 of Set 11 | westport
# Processing Record 38 of Set 11 | waingapu
# Processing Record 39 of Set 11 | acandi
# Processing Record 40 of Set 11 | saint-philippe
# Processing Record 41 of Set 11 | makakilo city
# Processing Record 42 of Set 11 | saint george
# Processing Record 43 of Set 11 | umea
# Processing Record 44 of Set 11 | te anau
# Processing Record 45 of Set 11 | prieska
# Processing Record 46 of Set 11 | guatavita
# Processing Record 47 of Set 11 | urumqi
# Processing Record 48 of Set 11 | marsa matruh
# Processing Record 49 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 11 | gouloure
# Processing Record 1 of Set 12 | pinhao
# Processing Record 2 of Set 12 | kungurtug
# Processing Record 3 of Set 12 | ormara
# Processing Record 4 of Set 12 | saint-francois
# Processing Record 5 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 12 | vila velha
# Processing Record 7 of Set 12 | miraflores
# Processing Record 8 of Set 12 | sangamner
# Processing Record 9 of Set 12 | biltine
# Processing Record 10 of Set 12 | salinopolis
# Processing Record 11 of Set 12 | curaca
# Processing Record 12 of Set 12 | sogdiondon
# City not found. Skipping...
# Processing Record 13 of Set 12 | seoul
# Processing Record 14 of Set 12 | nanning
# Processing Record 15 of Set 12 | henties bay
# Processing Record 16 of Set 12 | bukachacha
# Processing Record 17 of Set 12 | birao
# Processing Record 18 of Set 12 | kieta
# Processing Record 19 of Set 12 | rio gallegos
# Processing Record 20 of Set 12 | alpena
# Processing Record 21 of Set 12 | ilo
# Processing Record 22 of Set 12 | kamenka
# Processing Record 23 of Set 12 | tunceli
# Processing Record 24 of Set 12 | buy
# Processing Record 25 of Set 12 | jardim
# Processing Record 26 of Set 12 | tombouctou
# Processing Record 27 of Set 12 | taoudenni
# Processing Record 28 of Set 12 | chibuto
# Processing Record 29 of Set 12 | south venice
# Processing Record 30 of Set 12 | akyab
# Processing Record 31 of Set 12 | bayan
# Processing Record 32 of Set 12 | puerto narino
# Processing Record 33 of Set 12 | port augusta
# Processing Record 34 of Set 12 | altea
# Processing Record 35 of Set 12 | iquitos
# Processing Record 36 of Set 12 | rio rancho
# Processing Record 37 of Set 12 | yakima
# Processing Record 38 of Set 12 | malaya serdoba
# Processing Record 39 of Set 12 | burns lake
# Processing Record 40 of Set 12 | deputatskiy
# Processing Record 41 of Set 12 | les cayes
# Processing Record 42 of Set 12 | san cristobal
# Processing Record 43 of Set 12 | chumikan
# Processing Record 44 of Set 12 | bagan
# Processing Record 45 of Set 12 | salto
# Processing Record 46 of Set 12 | tigil
# Processing Record 47 of Set 12 | cuamba
# Processing Record 48 of Set 12 | kelso
# Processing Record 49 of Set 12 | troitsko-pechorsk
# Processing Record 50 of Set 12 | taizhou
# Processing Record 1 of Set 13 | haicheng
# Processing Record 2 of Set 13 | poplar bluff
# Processing Record 3 of Set 13 | kerman
# Processing Record 4 of Set 13 | maine-soroa
# Processing Record 5 of Set 13 | krasnovishersk
# Processing Record 6 of Set 13 | bogovarovo
# Processing Record 7 of Set 13 | walvis bay
# Processing Record 8 of Set 13 | nazare
# Processing Record 9 of Set 13 | bereda
# Processing Record 10 of Set 13 | goure
# Processing Record 11 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 12 of Set 13 | matara
# Processing Record 13 of Set 13 | inhambane
# Processing Record 14 of Set 13 | channel-port aux basques
# Processing Record 15 of Set 13 | kainantu
# Processing Record 16 of Set 13 | faya
# Processing Record 17 of Set 13 | auki
# Processing Record 18 of Set 13 | vestmanna
# Processing Record 19 of Set 13 | upata
# Processing Record 20 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 13 | mount gambier
# Processing Record 22 of Set 13 | sabaudia
# Processing Record 23 of Set 13 | petatlan
# Processing Record 24 of Set 13 | batemans bay
# Processing Record 25 of Set 13 | casper
# Processing Record 26 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 27 of Set 13 | prince rupert
# Processing Record 28 of Set 13 | sinnai
# Processing Record 29 of Set 13 | eureka
# Processing Record 30 of Set 13 | iskateley
# Processing Record 31 of Set 13 | jalu
# Processing Record 32 of Set 13 | buraydah
# Processing Record 33 of Set 13 | dekoa
# City not found. Skipping...
# Processing Record 34 of Set 13 | jumla
# Processing Record 35 of Set 13 | manokwari
# Processing Record 36 of Set 13 | aras
# Processing Record 37 of Set 13 | sao felix do xingu
# Processing Record 38 of Set 13 | jawad
# Processing Record 39 of Set 13 | north battleford
# Processing Record 40 of Set 13 | belmonte
# Processing Record 41 of Set 13 | ca mau
# Processing Record 42 of Set 13 | honiara
# Processing Record 43 of Set 13 | qasigiannguit
# Processing Record 44 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 13 | wejherowo
# Processing Record 46 of Set 13 | varhaug
# Processing Record 47 of Set 13 | tamasane
# Processing Record 48 of Set 13 | jamalpur
# Processing Record 49 of Set 13 | robertsport
# Processing Record 50 of Set 13 | finschhafen
# Processing Record 1 of Set 14 | narasaraopet
# Processing Record 2 of Set 14 | tessalit
# Processing Record 3 of Set 14 | royan
# Processing Record 4 of Set 14 | oreanda
# City not found. Skipping...
# Processing Record 5 of Set 14 | valparaiso
# Processing Record 6 of Set 14 | suez
# Processing Record 7 of Set 14 | edinburg
# Processing Record 8 of Set 14 | aloleng
# Processing Record 9 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 14 | bairiki
# Processing Record 11 of Set 14 | hsinchu
# Processing Record 12 of Set 14 | tandil
# Processing Record 13 of Set 14 | samana
# Processing Record 14 of Set 14 | lagunillas
# Processing Record 15 of Set 14 | morristown
# Processing Record 16 of Set 14 | hambantota
# Processing Record 17 of Set 14 | fazendas de almeirim
# Processing Record 18 of Set 14 | novodugino
# Processing Record 19 of Set 14 | nishihara
# Processing Record 20 of Set 14 | udachnyy
# Processing Record 21 of Set 14 | bela
# Processing Record 22 of Set 14 | byron bay
# Processing Record 23 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 24 of Set 14 | lake city
# Processing Record 25 of Set 14 | manado
# Processing Record 26 of Set 14 | chulym
# Processing Record 27 of Set 14 | viedma
# Processing Record 28 of Set 14 | boudry
# Processing Record 29 of Set 14 | santa barbara
# Processing Record 30 of Set 14 | blackwater
# Processing Record 31 of Set 14 | hella
# Processing Record 32 of Set 14 | ornskoldsvik
# Processing Record 33 of Set 14 | tambopata
# Processing Record 34 of Set 14 | natal
# Processing Record 35 of Set 14 | bucerias
# Processing Record 36 of Set 14 | basoko
# Processing Record 37 of Set 14 | ust-nera
# Processing Record 38 of Set 14 | farafangana
# Processing Record 39 of Set 14 | husavik
# Processing Record 40 of Set 14 | salinas
# Processing Record 41 of Set 14 | simoes
# Processing Record 42 of Set 14 | klamath falls
# Processing Record 43 of Set 14 | elbistan
# Processing Record 44 of Set 14 | tocopilla
# Processing Record 45 of Set 14 | clearlake
# Processing Record 46 of Set 14 | trindade
# Processing Record 47 of Set 14 | sirjan
# Processing Record 48 of Set 14 | verkhnyaya inta
# Processing Record 49 of Set 14 | kudahuvadhoo
# Processing Record 50 of Set 14 | whitehorse
# Processing Record 1 of Set 15 | bambanglipuro
# Processing Record 2 of Set 15 | ancud
# Processing Record 3 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 15 | abu samrah
# Processing Record 5 of Set 15 | quthing
# Processing Record 6 of Set 15 | qandala
# Processing Record 7 of Set 15 | kristiinankaupunki
# Processing Record 8 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 9 of Set 15 | bolshaya irba
# City not found. Skipping...
# Processing Record 10 of Set 15 | onega
# Processing Record 11 of Set 15 | donskoye
# Processing Record 12 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 13 of Set 15 | bahia de caraquez
# Processing Record 14 of Set 15 | polur
# Processing Record 15 of Set 15 | camopi
# Processing Record 16 of Set 15 | baculin
# Processing Record 17 of Set 15 | kyabram
# Processing Record 18 of Set 15 | kavieng
# Processing Record 19 of Set 15 | wattegama
# Processing Record 20 of Set 15 | along
# Processing Record 21 of Set 15 | gboko
# Processing Record 22 of Set 15 | artyshta
# Processing Record 23 of Set 15 | victor harbor
# Processing Record 24 of Set 15 | kalisz
# Processing Record 25 of Set 15 | tateyama
# Processing Record 26 of Set 15 | barabai
# Processing Record 27 of Set 15 | poya
# Processing Record 28 of Set 15 | shakhrinau
# City not found. Skipping...
# Processing Record 29 of Set 15 | siguiri
# Processing Record 30 of Set 15 | el espinal
# Processing Record 31 of Set 15 | cape coast
# Processing Record 32 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 15 | pabna
# Processing Record 34 of Set 15 | igarka
# Processing Record 35 of Set 15 | nongstoin
# Processing Record 36 of Set 15 | ballina
# Processing Record 37 of Set 15 | beneditinos
# Processing Record 38 of Set 15 | sydney
# Processing Record 39 of Set 15 | qinhuangdao
# Processing Record 40 of Set 15 | trincomalee
# Processing Record 41 of Set 15 | sterling
# Processing Record 42 of Set 15 | la libertad
# Processing Record 43 of Set 15 | gravdal
# Processing Record 44 of Set 15 | sidi qasim
# City not found. Skipping...
# Processing Record 45 of Set 15 | voh
# Processing Record 46 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 47 of Set 15 | lewisporte
# Processing Record 48 of Set 15 | xai-xai
# Processing Record 49 of Set 15 | verkhnyaya toyma
# Processing Record 50 of Set 15 | kwidzyn
# Processing Record 1 of Set 16 | yuxia
# Processing Record 2 of Set 16 | kunyang
# Processing Record 3 of Set 16 | kota
# Processing Record 4 of Set 16 | villanueva de la serena
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
city_data_df.to_csv("WeatherPy_Database.csv")
